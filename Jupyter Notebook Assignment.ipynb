# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> KoDee Martin </b> <br>
#     Currently a Technology and Merchandising Lead. <br>
#     Seeking new job as a Data Analyst/Data Scientist.

# %% [markdown]
# <i> I am interested in Data Science because I enjoy the idea of using data to analyze and solve almost any question that has quantifiable information.  I believe we are going to get even more reliant on technology, and more technology means more data.  For us to understand, learn, and improve in this technological world, we need to retrieve the data, understand it, and move forward to make the appropriate improvements as efficiently and effectively as possible. </i>

# %% [markdown]
# ### Cell 5 is going to print the statement that is most important to me:

# %%
print("I am ready for a career change into Data Science!")
# Out:
# I am ready for a career change into Data Science!

# %% [markdown]
# These are some reasons why I want a career change into Data Science:<br>
# <ul>
#     <li>Salary Increase!</li>
#     <blockquote>I am most excited about this reason!</blockquote>
#     <li>Daytime Hours</li>
#     <li>Consistent Schedule</li>
#     <li><strike>Lack of Opportunity</strike></li>
# </ul>
